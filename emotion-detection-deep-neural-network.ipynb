# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import os
import tensorflow as tf
import keras
import cv2

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

from tensorflow.keras.layers import *
from tensorflow.keras import layers , models, optimizers
from tensorflow.keras.models import Sequential, Model


from tensorflow.keras.applications import ResNet50V2


from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau


from tensorflow.keras.utils import plot_model
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# define a  function to caculate the number of each emotion classes
train_dir = '/kaggle/input/fer2013/train/'
test_dir = '/kaggle/input/fer2013/test/'

def Classes_Count( path, name):
    Classes_Dict = {}
    
    for Class in os.listdir(path):
        
        Full_Path = os.path.join(path, Class)
        Classes_Dict[Class] = len(os.listdir(Full_Path))
        
    df = pd.DataFrame(Classes_Dict, index=[name])
    
    return df

Train_Count = Classes_Count(train_dir, 'Train').transpose().sort_values(by="Train", ascending=False)
Test_Count = Classes_Count(test_dir, 'Test').transpose().sort_values(by="Test", ascending=False)

# %%
pd.concat([Train_Count,Test_Count] , axis=1)
# Out:
#           Train  Test
# happy      7215  1774
# neutral    4965  1233
# sad        4830  1247
# fear       4097  1024
# angry      3995   958
# surprise   3171   831
# disgust     436   111

# %% [markdown]
# **Explanation:** The data set is unbalanced

# %%
Train_Count.plot(kind='barh')
plt.title('Train Data Distribution')
plt.xlabel('Number of images')
plt.ylabel('Emotions')
plt.show()

# %% [markdown]
# **Explanation:** The number of happy faces is about 20 times tha disgust faces in training data set.

# %%
Test_Count.plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# **Explanation:** The number of happy faces is about 17 times tha disgust faces in test data set.

# %% [markdown]
# ### **Show a batch of images**

# %%
plt.style.use('default')
plt.figure(figsize = (25, 8))
image_count = 1
BASE_URL = '/kaggle/input/fer2013/train/'

for directory in os.listdir(BASE_URL):
    if directory[0] != '.':
        for i, file in enumerate(os.listdir(BASE_URL +'/'+ directory)):
            if i == 1:
                break
            else:
                fig = plt.subplot(1, 7, image_count)
                image_count += 1
                image = cv2.imread(BASE_URL + directory + '/' + file)
                plt.imshow(image)
                plt.title(directory, fontsize = 20)

# %% [markdown]
# **Explanation:** Show how the images in the data set look like.

# %%
img_shape = 48
batch_size = 64
train_data_path = '/kaggle/input/fer2013/train/'
test_data_path = '/kaggle/input/fer2013/test/'

# %%
#using data generators to generate batches of images 
train_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
        # Data Augmentation
        rotation_range=10,
        zoom_range=0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,                                        
        fill_mode='nearest',
    )


test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

train_data = train_preprocessor.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)


test_data = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### **CNN Model**

# %%
def Create_CNN_Model():
    
    model = Sequential()
    
    #CNN1
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=(img_shape, img_shape, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN2
    model.add(Conv2D(64, (3,3), activation='relu', ))
    model.add(BatchNormalization())
    model.add(Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN3
    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    
    #Output
    model.add(Flatten())
    
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(7,activation='softmax'))
    
    
    return model

# %%
CNN_Model = Create_CNN_Model()

CNN_Model.summary()

CNN_Model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        896
#
#  batch_normalization (BatchN  (None, 46, 46, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 21, 21, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 9, 9, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 9, 9, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 9, 9, 256)         295168
#
#  batch_normalization_5 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 1024)              6554624
#
#  batch_normalization_6 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  batch_normalization_8 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  batch_normalization_9 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_10 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  batch_normalization_11 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 7,837,895
# Trainable params: 7,832,519
# Non-trainable params: 5,376
# _________________________________________________________________

# %% [markdown]
# ### **Specifying CNN Callbacks**

# %%
# Create Callback Checkpoint
checkpoint_path = "CNN_Model_Checkpoint"

Checkpoint = ModelCheckpoint(checkpoint_path, monitor="val_accuracy", save_best_only=True)


Early_Stopping = EarlyStopping(monitor = 'val_accuracy', patience = 15, restore_best_weights = True, verbose=1)

Reducing_LR = tf.keras.callbacks.ReduceLROnPlateau( monitor='val_loss',
                                                  factor=0.2,
                                                  patience=2,
#                                                   min_lr=0.000005,
                                                  verbose=1)

callbacks = [Early_Stopping, Reducing_LR]

steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %% [markdown]
# ### **CNN Training**

# %%
CNN_history = CNN_Model.fit( train_data , validation_data= test_data , epochs=50, batch_size= batch_size,
                            callbacks=callbacks, steps_per_epoch= steps_per_epoch, validation_steps=validation_steps)
# Out:
# Epoch 1/50
# 2024-04-22 10:47:31.815406: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 448/448 [==============================] - 161s 332ms/step - loss: 2.0229 - accuracy: 0.1995 - val_loss: 1.7927 - val_accuracy: 0.2610 - lr: 0.0010
# Epoch 2/50
# 448/448 [==============================] - 59s 133ms/step - loss: 1.7615 - accuracy: 0.2880 - val_loss: 1.6207 - val_accuracy: 0.3570 - lr: 0.0010
# Epoch 3/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.6264 - accuracy: 0.3538 - val_loss: 1.5935 - val_accuracy: 0.3698 - lr: 0.0010
# Epoch 4/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.5140 - accuracy: 0.4105 - val_loss: 1.4125 - val_accuracy: 0.4556 - lr: 0.0010
# Epoch 5/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.4210 - accuracy: 0.4561 - val_loss: 1.3874 - val_accuracy: 0.4741 - lr: 0.0010
# Epoch 6/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.3646 - accuracy: 0.4787 - val_loss: 1.3870 - val_accuracy: 0.4795 - lr: 0.0010
# Epoch 7/50
# 448/448 [==============================] - 60s 133ms/step - loss: 1.3115 - accuracy: 0.5014 - val_loss: 1.2265 - val_accuracy: 0.5307 - lr: 0.0010
# Epoch 8/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.2812 - accuracy: 0.5193 - val_loss: 1.1736 - val_accuracy: 0.5434 - lr: 0.0010
# Epoch 9/50
# 448/448 [==============================] - 57s 127ms/step - loss: 1.2574 - accuracy: 0.5270 - val_loss: 1.1614 - val_accuracy: 0.5586 - lr: 0.0010
# Epoch 10/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.2354 - accuracy: 0.5388 - val_loss: 1.1899 - val_accuracy: 0.5406 - lr: 0.0010
# Epoch 11/50
# 448/448 [==============================] - 60s 134ms/step - loss: 1.2202 - accuracy: 0.5455 - val_loss: 1.1460 - val_accuracy: 0.5686 - lr: 0.0010
# Epoch 12/50
# 448/448 [==============================] - 63s 140ms/step - loss: 1.1895 - accuracy: 0.5572 - val_loss: 1.1251 - val_accuracy: 0.5752 - lr: 0.0010
# Epoch 13/50
# 448/448 [==============================] - 59s 133ms/step - loss: 1.1739 - accuracy: 0.5632 - val_loss: 1.0942 - val_accuracy: 0.5953 - lr: 0.0010
# Epoch 14/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.1581 - accuracy: 0.5709 - val_loss: 1.1365 - val_accuracy: 0.5829 - lr: 0.0010
# Epoch 15/50
# 448/448 [==============================] - ETA: 0s - loss: 1.1482 - accuracy: 0.5745
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 448/448 [==============================] - 57s 128ms/step - loss: 1.1482 - accuracy: 0.5745 - val_loss: 1.1540 - val_accuracy: 0.5590 - lr: 0.0010
# Epoch 16/50
# 448/448 [==============================] - 57s 128ms/step - loss: 1.0989 - accuracy: 0.5957 - val_loss: 1.0036 - val_accuracy: 0.6279 - lr: 2.0000e-04
# Epoch 17/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.0743 - accuracy: 0.6040 - val_loss: 1.0046 - val_accuracy: 0.6251 - lr: 2.0000e-04
# Epoch 18/50
# 448/448 [==============================] - 63s 140ms/step - loss: 1.0565 - accuracy: 0.6110 - val_loss: 0.9866 - val_accuracy: 0.6295 - lr: 2.0000e-04
# Epoch 19/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.0519 - accuracy: 0.6153 - val_loss: 0.9855 - val_accuracy: 0.6359 - lr: 2.0000e-04
# Epoch 20/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.0487 - accuracy: 0.6127 - val_loss: 0.9687 - val_accuracy: 0.6396 - lr: 2.0000e-04
# Epoch 21/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.0378 - accuracy: 0.6194 - val_loss: 0.9694 - val_accuracy: 0.6423 - lr: 2.0000e-04
# Epoch 22/50
# 448/448 [==============================] - ETA: 0s - loss: 1.0316 - accuracy: 0.6183
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 448/448 [==============================] - 58s 131ms/step - loss: 1.0316 - accuracy: 0.6183 - val_loss: 0.9759 - val_accuracy: 0.6396 - lr: 2.0000e-04
# Epoch 23/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.0178 - accuracy: 0.6287 - val_loss: 0.9629 - val_accuracy: 0.6469 - lr: 4.0000e-05
# Epoch 24/50
# 448/448 [==============================] - 59s 133ms/step - loss: 1.0223 - accuracy: 0.6226 - val_loss: 0.9597 - val_accuracy: 0.6459 - lr: 4.0000e-05
# Epoch 25/50
# 448/448 [==============================] - 58s 128ms/step - loss: 1.0137 - accuracy: 0.6282 - val_loss: 0.9584 - val_accuracy: 0.6440 - lr: 4.0000e-05
# Epoch 26/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.0092 - accuracy: 0.6311 - val_loss: 0.9602 - val_accuracy: 0.6449 - lr: 4.0000e-05
# Epoch 27/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.0090 - accuracy: 0.6300 - val_loss: 0.9541 - val_accuracy: 0.6496 - lr: 4.0000e-05
# Epoch 28/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.0107 - accuracy: 0.6298 - val_loss: 0.9529 - val_accuracy: 0.6484 - lr: 4.0000e-05
# Epoch 29/50
# 448/448 [==============================] - 58s 128ms/step - loss: 1.0026 - accuracy: 0.6308 - val_loss: 0.9529 - val_accuracy: 0.6484 - lr: 4.0000e-05
# Epoch 30/50
# 448/448 [==============================] - 56s 126ms/step - loss: 1.0058 - accuracy: 0.6305 - val_loss: 0.9502 - val_accuracy: 0.6496 - lr: 4.0000e-05
# Epoch 31/50
# 448/448 [==============================] - 65s 145ms/step - loss: 0.9987 - accuracy: 0.6331 - val_loss: 0.9538 - val_accuracy: 0.6470 - lr: 4.0000e-05
# Epoch 32/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9998 - accuracy: 0.6350
# Epoch 32: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9998 - accuracy: 0.6350 - val_loss: 0.9534 - val_accuracy: 0.6490 - lr: 4.0000e-05
# Epoch 33/50
# 448/448 [==============================] - 60s 134ms/step - loss: 0.9950 - accuracy: 0.6358 - val_loss: 0.9501 - val_accuracy: 0.6480 - lr: 8.0000e-06
# Epoch 34/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9895 - accuracy: 0.6368
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9895 - accuracy: 0.6368 - val_loss: 0.9511 - val_accuracy: 0.6491 - lr: 8.0000e-06
# Epoch 35/50
# 448/448 [==============================] - 57s 128ms/step - loss: 0.9909 - accuracy: 0.6378 - val_loss: 0.9479 - val_accuracy: 0.6496 - lr: 1.6000e-06
# Epoch 36/50
# 448/448 [==============================] - 58s 128ms/step - loss: 0.9890 - accuracy: 0.6356 - val_loss: 0.9489 - val_accuracy: 0.6498 - lr: 1.6000e-06
# Epoch 37/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9917 - accuracy: 0.6360
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 448/448 [==============================] - 57s 127ms/step - loss: 0.9917 - accuracy: 0.6360 - val_loss: 0.9500 - val_accuracy: 0.6500 - lr: 1.6000e-06
# Epoch 38/50
# 448/448 [==============================] - 56s 126ms/step - loss: 0.9918 - accuracy: 0.6383 - val_loss: 0.9509 - val_accuracy: 0.6496 - lr: 3.2000e-07
# Epoch 39/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9879 - accuracy: 0.6342
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 448/448 [==============================] - 63s 125ms/step - loss: 0.9879 - accuracy: 0.6342 - val_loss: 0.9503 - val_accuracy: 0.6490 - lr: 3.2000e-07
# Epoch 40/50
# 448/448 [==============================] - 56s 125ms/step - loss: 0.9927 - accuracy: 0.6401 - val_loss: 0.9491 - val_accuracy: 0.6507 - lr: 6.4000e-08
# Epoch 41/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9889 - accuracy: 0.6397
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 448/448 [==============================] - 57s 126ms/step - loss: 0.9889 - accuracy: 0.6397 - val_loss: 0.9506 - val_accuracy: 0.6486 - lr: 6.4000e-08
# Epoch 42/50
# 448/448 [==============================] - 62s 138ms/step - loss: 0.9905 - accuracy: 0.6380 - val_loss: 0.9488 - val_accuracy: 0.6493 - lr: 1.2800e-08
# Epoch 43/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9928 - accuracy: 0.6379
# Epoch 43: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 448/448 [==============================] - 57s 126ms/step - loss: 0.9928 - accuracy: 0.6379 - val_loss: 0.9510 - val_accuracy: 0.6491 - lr: 1.2800e-08
# Epoch 44/50
# 448/448 [==============================] - 57s 128ms/step - loss: 0.9955 - accuracy: 0.6341 - val_loss: 0.9471 - val_accuracy: 0.6514 - lr: 2.5600e-09
# Epoch 45/50
# 448/448 [==============================] - 57s 127ms/step - loss: 0.9899 - accuracy: 0.6362 - val_loss: 0.9466 - val_accuracy: 0.6500 - lr: 2.5600e-09
# Epoch 46/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9874 - accuracy: 0.6354 - val_loss: 0.9468 - val_accuracy: 0.6512 - lr: 2.5600e-09
# Epoch 47/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9927 - accuracy: 0.6352
# Epoch 47: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 448/448 [==============================] - 57s 126ms/step - loss: 0.9927 - accuracy: 0.6352 - val_loss: 0.9503 - val_accuracy: 0.6507 - lr: 2.5600e-09
# Epoch 48/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9950 - accuracy: 0.6337 - val_loss: 0.9460 - val_accuracy: 0.6512 - lr: 5.1200e-10
# Epoch 49/50
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9973 - accuracy: 0.6334 - val_loss: 0.9471 - val_accuracy: 0.6512 - lr: 5.1200e-10
# Epoch 50/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9986 - accuracy: 0.6359
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 448/448 [==============================] - 58s 129ms/step - loss: 0.9986 - accuracy: 0.6359 - val_loss: 0.9496 - val_accuracy: 0.6490 - lr: 5.1200e-10

# %% [markdown]
# ### **Visualising CNN Loss and Accuracy**

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "training_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "training_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.legend()
  
  #plt.tight_layout()

# %%
plot_curves(CNN_history)

# %% [markdown]
# **Explanation:** CNN model demonstrated a decline in training and validation losses, along with an uptick in accuracies, signifying effective learning.  However, the CNN model was more consistent between training and validation metrics, indicating better generalization.

# %% [markdown]
# ### **Evaluating CNN Model**

# %%
CNN_Score = CNN_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(CNN_Score[0]))
print("Test Accuracy: {:.2f}%".format(CNN_Score[1] * 100))
# Out:
# 113/113 [==============================] - 6s 57ms/step - loss: 3.9567 - accuracy: 0.6481
#     Test Loss: 3.95672
# Test Accuracy: 64.81%

# %% [markdown]
# ###   **NN Confusion Matrix**

# %%
CNN_Predictions = CNN_Model.predict(test_data)


CNN_Predictions = np.argmax(CNN_Predictions, axis=1)
# Out:
# 113/113 [==============================] - 7s 58ms/step

# %%
test_data.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

fig, ax= plt.subplots(figsize=(15,10))

cm=confusion_matrix(test_data.labels, CNN_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('CNN Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'CNN Confusion Matrix')

# %% [markdown]
# ### **ResNet50V2 Model**

# %%
img_shape = 224
batch_size = 64
train_data_path = '/kaggle/input/fer2013/train/'
test_data_path = '/kaggle/input/fer2013/test/'

# %%
train_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
        rotation_range=10,
        zoom_range=0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,                                        
        fill_mode='nearest',
    )


test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

train_data = train_preprocessor.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)

test_data = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### **Fine-Tuning ResNet50V2**

# %%
# 224,224,3
ResNet50V2 = tf.keras.applications.ResNet50V2(input_shape=(224, 224, 3),
                                               include_top= False,
                                               weights='imagenet'
                                               )

#ResNet50V2.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 0s 0us/step

# %%
ResNet50V2.trainable = True

for layer in ResNet50V2.layers[:-50]:
    layer.trainable = False

# %% [markdown]
# ### **Customed Output Layer**

# %%
def Create_ResNet50V2_Model():

    model = Sequential([
                      ResNet50V2,
                      Dropout(.25),
                      BatchNormalization(),
                      Flatten(),
                      Dense(64, activation='relu'),
                      BatchNormalization(),
                      Dropout(.5),
                      Dense(7,activation='softmax')
                    ])
    return model

# %%
ResNet50V2_Model = Create_ResNet50V2_Model()

ResNet50V2_Model.summary()

ResNet50V2_Model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  dropout_9 (Dropout)         (None, 7, 7, 2048)        0
#
#  batch_normalization_12 (Bat  (None, 7, 7, 2048)       8192
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_7 (Dense)             (None, 64)                6422592
#
#  batch_normalization_13 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_8 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 29,996,295
# Trainable params: 22,779,527
# Non-trainable params: 7,216,768
# _________________________________________________________________

# %%
checkpoint_path = "ResNet50V2_Model_Checkpoint"

Checkpoint = ModelCheckpoint(checkpoint_path, monitor="val_accuracy", save_best_only=True)


Early_Stopping = EarlyStopping(monitor = 'val_accuracy', patience = 7, restore_best_weights = True, verbose=1)


Reducing_LR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                  factor=0.2,
                                                  patience=2,
#                                                   min_lr=0.00005,
                                                  verbose=1)

callbacks = [Early_Stopping, Reducing_LR]

steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %% [markdown]
# ### **ResNet Training**

# %%
ResNet50V2_history = ResNet50V2_Model.fit(train_data ,validation_data = test_data , epochs=30, batch_size=batch_size,
                                         callbacks = callbacks, steps_per_epoch=steps_per_epoch, validation_steps=validation_steps)
# Out:
# Epoch 1/30
# 2024-04-22 11:39:43.411082: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_9/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 448/448 [==============================] - 367s 791ms/step - loss: 1.5853 - accuracy: 0.4568 - val_loss: 1.9257 - val_accuracy: 0.5396 - lr: 0.0010
# Epoch 2/30
# 448/448 [==============================] - 361s 805ms/step - loss: 1.2585 - accuracy: 0.5495 - val_loss: 1.2139 - val_accuracy: 0.5876 - lr: 0.0010
# Epoch 3/30
# 448/448 [==============================] - 360s 803ms/step - loss: 1.1895 - accuracy: 0.5785 - val_loss: 1.6386 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 4/30
# 448/448 [==============================] - ETA: 0s - loss: 1.1578 - accuracy: 0.5885
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 448/448 [==============================] - 361s 806ms/step - loss: 1.1578 - accuracy: 0.5885 - val_loss: 1.3151 - val_accuracy: 0.5201 - lr: 0.0010
# Epoch 5/30
# 448/448 [==============================] - 369s 824ms/step - loss: 1.1222 - accuracy: 0.6020 - val_loss: 1.0030 - val_accuracy: 0.6251 - lr: 2.0000e-04
# Epoch 6/30
# 448/448 [==============================] - 373s 832ms/step - loss: 1.0329 - accuracy: 0.6279 - val_loss: 0.9995 - val_accuracy: 0.6293 - lr: 2.0000e-04
# Epoch 7/30
# 448/448 [==============================] - 378s 844ms/step - loss: 0.9869 - accuracy: 0.6447 - val_loss: 0.9638 - val_accuracy: 0.6449 - lr: 2.0000e-04
# Epoch 8/30
# 448/448 [==============================] - 374s 835ms/step - loss: 0.9658 - accuracy: 0.6541 - val_loss: 0.9618 - val_accuracy: 0.6528 - lr: 2.0000e-04
# Epoch 9/30
# 448/448 [==============================] - 370s 826ms/step - loss: 0.9358 - accuracy: 0.6634 - val_loss: 0.9581 - val_accuracy: 0.6494 - lr: 2.0000e-04
# Epoch 10/30
# 448/448 [==============================] - 369s 823ms/step - loss: 0.9188 - accuracy: 0.6704 - val_loss: 0.9632 - val_accuracy: 0.6508 - lr: 2.0000e-04
# Epoch 11/30
# 448/448 [==============================] - 361s 805ms/step - loss: 0.8938 - accuracy: 0.6800 - val_loss: 0.9397 - val_accuracy: 0.6562 - lr: 2.0000e-04
# Epoch 12/30
# 448/448 [==============================] - 369s 822ms/step - loss: 0.8817 - accuracy: 0.6821 - val_loss: 0.9685 - val_accuracy: 0.6458 - lr: 2.0000e-04
# Epoch 13/30
# 448/448 [==============================] - ETA: 0s - loss: 0.8492 - accuracy: 0.6927
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 448/448 [==============================] - 367s 819ms/step - loss: 0.8492 - accuracy: 0.6927 - val_loss: 0.9473 - val_accuracy: 0.6582 - lr: 2.0000e-04
# Epoch 14/30
# 448/448 [==============================] - 373s 833ms/step - loss: 0.8031 - accuracy: 0.7149 - val_loss: 0.9138 - val_accuracy: 0.6703 - lr: 4.0000e-05
# Epoch 15/30
# 448/448 [==============================] - 352s 784ms/step - loss: 0.7772 - accuracy: 0.7239 - val_loss: 0.9156 - val_accuracy: 0.6734 - lr: 4.0000e-05
# Epoch 16/30
# 448/448 [==============================] - 361s 806ms/step - loss: 0.7618 - accuracy: 0.7283 - val_loss: 0.9136 - val_accuracy: 0.6748 - lr: 4.0000e-05
# Epoch 17/30
# 448/448 [==============================] - 362s 807ms/step - loss: 0.7449 - accuracy: 0.7319 - val_loss: 0.9244 - val_accuracy: 0.6752 - lr: 4.0000e-05
# Epoch 18/30
# 448/448 [==============================] - ETA: 0s - loss: 0.7406 - accuracy: 0.7376
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 448/448 [==============================] - 343s 764ms/step - loss: 0.7406 - accuracy: 0.7376 - val_loss: 0.9249 - val_accuracy: 0.6748 - lr: 4.0000e-05
# Epoch 19/30
# 448/448 [==============================] - 359s 802ms/step - loss: 0.7176 - accuracy: 0.7447 - val_loss: 0.9213 - val_accuracy: 0.6772 - lr: 8.0000e-06
# Epoch 20/30
# 448/448 [==============================] - ETA: 0s - loss: 0.7095 - accuracy: 0.7501
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 448/448 [==============================] - 356s 794ms/step - loss: 0.7095 - accuracy: 0.7501 - val_loss: 0.9231 - val_accuracy: 0.6772 - lr: 8.0000e-06
# Epoch 21/30
# 448/448 [==============================] - 346s 773ms/step - loss: 0.7035 - accuracy: 0.7496 - val_loss: 0.9238 - val_accuracy: 0.6779 - lr: 1.6000e-06
# Epoch 22/30
# 448/448 [==============================] - ETA: 0s - loss: 0.7095 - accuracy: 0.7475
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 448/448 [==============================] - 360s 802ms/step - loss: 0.7095 - accuracy: 0.7475 - val_loss: 0.9241 - val_accuracy: 0.6787 - lr: 1.6000e-06
# Epoch 23/30
# 448/448 [==============================] - 354s 790ms/step - loss: 0.7116 - accuracy: 0.7462 - val_loss: 0.9244 - val_accuracy: 0.6790 - lr: 3.2000e-07
# Epoch 24/30
# 448/448 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.7488
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 448/448 [==============================] - 367s 819ms/step - loss: 0.7046 - accuracy: 0.7488 - val_loss: 0.9227 - val_accuracy: 0.6779 - lr: 3.2000e-07
# Epoch 25/30
# 448/448 [==============================] - 364s 813ms/step - loss: 0.7077 - accuracy: 0.7472 - val_loss: 0.9239 - val_accuracy: 0.6780 - lr: 6.4000e-08
# Epoch 26/30
# 448/448 [==============================] - ETA: 0s - loss: 0.7108 - accuracy: 0.7485
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 448/448 [==============================] - 353s 788ms/step - loss: 0.7108 - accuracy: 0.7485 - val_loss: 0.9229 - val_accuracy: 0.6790 - lr: 6.4000e-08
# Epoch 27/30
# 448/448 [==============================] - 342s 764ms/step - loss: 0.7107 - accuracy: 0.7461 - val_loss: 0.9219 - val_accuracy: 0.6782 - lr: 1.2800e-08
# Epoch 28/30
# 448/448 [==============================] - ETA: 0s - loss: 0.7072 - accuracy: 0.7488
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 448/448 [==============================] - 346s 771ms/step - loss: 0.7072 - accuracy: 0.7488 - val_loss: 0.9236 - val_accuracy: 0.6784 - lr: 1.2800e-08
# Epoch 29/30
# 448/448 [==============================] - 350s 781ms/step - loss: 0.7001 - accuracy: 0.7525 - val_loss: 0.9233 - val_accuracy: 0.6789 - lr: 2.5600e-09
# Epoch 30/30
# 448/448 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.7533Restoring model weights from the end of the best epoch: 23.
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 448/448 [==============================] - 351s 784ms/step - loss: 0.7014 - accuracy: 0.7533 - val_loss: 0.9235 - val_accuracy: 0.6780 - lr: 2.5600e-09
# Epoch 30: early stopping

# %% [markdown]
# ### **Visualising ResNet Loss and Accuracy**

# %%
plot_curves(ResNet50V2_history)

# %% [markdown]
# ### **Evaluating ResNet50V2**

# %%
ResNet50V2_Score = ResNet50V2_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(ResNet50V2_Score[0]))
print("Test Accuracy: {:.2f}%".format(ResNet50V2_Score[1] * 100))
# Out:
# 113/113 [==============================] - 18s 155ms/step - loss: 0.9234 - accuracy: 0.6794
#     Test Loss: 0.92336
# Test Accuracy: 67.94%

# %% [markdown]
# ### **ResNet Confusion Matrix**

# %%
ResNet50V2_Predictions = ResNet50V2_Model.predict(test_data)


ResNet50V2_Predictions = np.argmax(ResNet50V2_Predictions, axis=1)
# Out:
# 113/113 [==============================] - 19s 161ms/step

# %%
fig , ax= plt.subplots(figsize=(15,10))

cm=confusion_matrix(test_data.labels, ResNet50V2_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('ResNet50V2 Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'ResNet50V2 Confusion Matrix')

# %% [markdown]
# ### **5Shuffling Test Data**

# %%
Emotion_Classes = ['Angry', 
                  'Disgust', 
                  'Fear', 
                  'Happy', 
                  'Neutral', 
                  'Sad', 
                  'Surprise']

# %%
# Shuffling Test Data to show diffrent classes
test_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
    )

test_generator = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(48,48),
    color_mode="rgb",
    shuffle=True,
    batch_size=batch_size,
)
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### **CNN Predictions**

# %%
Random_batch = np.random.randint(0, len(test_generator) - 1)

Random_Img_Index = np.random.randint(0, batch_size - 1 , 10)

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(25, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):

    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]

    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]])

    Model_Prediction = np.argmax(CNN_Model.predict( tf.expand_dims(Random_Img, axis=0) , verbose=0))

    ax.imshow(Random_Img)

    if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction]:
          color = "green"
    else:
          color = "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)
plt.show()
plt.tight_layout()

# %% [markdown]
# **Explanation:** The CNN model have a good performance in predicting new image.

# %% [markdown]
# ### **ResNet50V2 Predictions**

# %%
test_preprocessor = ImageDataGenerator(
        rescale = 1 / 255.,
    )

test_generator = test_preprocessor.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(224,224),
    color_mode="rgb",
    shuffle=True,
    batch_size=batch_size,
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
Random_batch = np.random.randint(0, len(test_generator) - 1)

Random_Img_Index = np.random.randint(0, batch_size - 1 , 10)

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(25, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):

    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]

    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]])

    Model_Prediction = np.argmax(ResNet50V2_Model.predict( tf.expand_dims(Random_Img, axis=0) , verbose=0))

    ax.imshow(Random_Img)

    if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction]:
          color = "green"
    else:
          color = "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)
plt.show()
plt.tight_layout()

# %% [markdown]
# ## **Save Models**

# %%
CNN_Model.save("CNN_Model.h5")

ResNet50V2_Model.save("ResNet50V2_Model.h5")
